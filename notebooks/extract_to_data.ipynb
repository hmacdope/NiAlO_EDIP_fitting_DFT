# %%
import pyiron
from pyiron.project import Project
pr = Project('import_and_change_format')
import ase
from ase.io.lammpsdata import write_lammps_data

# %%
path_to_import = "/store/Terry_project/NiAlO_EDIP_fitting_DFT/DATA"
pr.import_from_path(path=path_to_import, recursive=True)
# Out:
# SlabAlO2-s19 SlabAlO2_s19
# job was stored with the job ID  1
# SlabNiO2-s16 SlabNiO2_s16
# job was stored with the job ID  2
# PureAl PureAl
# job was stored with the job ID  3
# Ni-slab-Olayer2 Ni_slab_Olayer2
# job was stored with the job ID  4
# SlabNiO2-s27 SlabNiO2_s27
# job was stored with the job ID  5
# SlabNiO2-s08 SlabNiO2_s08
# job was stored with the job ID  6
# SlabNiO2-s17 SlabNiO2_s17
# job was stored with the job ID  7
# O4-2 O4_2
# job was stored with the job ID  8
# Al2O3-O2 Al2O3_O2
# job was stored with the job ID  9
# SlabAlO2-s15 SlabAlO2_s15
# job was stored with the job ID  10
# SlabNiO2-s02 SlabNiO2_s02
# job was stored with the job ID  11
# SlabAlO2-s24 SlabAlO2_s24
# job was stored with the job ID  12
# SlabAlO2-s17 SlabAlO2_s17
# job was stored with the job ID  13
# PureNi PureNi
# job was stored with the job ID  14
# O4-1 O4_1
# job was stored with the job ID  15
# SlabAlO2-s22 SlabAlO2_s22
# job was stored with the job ID  16
# Al2O3-Olayer1 Al2O3_Olayer1
# job was stored with the job ID  17
# SlabNiO2-s21 SlabNiO2_s21
# job was stored with the job ID  18
# NiO-supercell NiO_supercell
# job was stored with the job ID  19
# NiO-Slab-O2 NiO_Slab_O2
# job was stored with the job ID  20
# Al-slab-Olayer1 Al_slab_Olayer1
# job was stored with the job ID  21
# SlabAlO2-s16 SlabAlO2_s16
# job was stored with the job ID  22
# Al-slab-Olayer4 Al_slab_Olayer4
# job was stored with the job ID  23
# NiO-2 NiO_2
# job was stored with the job ID  24
# O2 O2
# job was stored with the job ID  25
# SlabNiO-1 SlabNiO_1
# job was stored with the job ID  26
# Al-slab-Olayer2 Al_slab_Olayer2
# job was stored with the job ID  27
# SlabAlO2-s6 SlabAlO2_s6
# job was stored with the job ID  28
# Al2O3-Olayer4 Al2O3_Olayer4
# job was stored with the job ID  29
# SlabAlO2-2 SlabAlO2_2
# job was stored with the job ID  30
# Al2O3-trigonal Al2O3_trigonal
# job was stored with the job ID  31
# SlabAlO2-s7 SlabAlO2_s7
# job was stored with the job ID  32
# SlabAlO2-s9 SlabAlO2_s9
# job was stored with the job ID  33
# SlabAlO2-1 SlabAlO2_1
# job was stored with the job ID  34
# SlabNiO2-s28 SlabNiO2_s28
# job was stored with the job ID  35
# SlabNiO2-s03 SlabNiO2_s03
# job was stored with the job ID  36
# SlabNiO2-s13 SlabNiO2_s13
# job was stored with the job ID  37
# SlabNiO2-s14 SlabNiO2_s14
# job was stored with the job ID  38
# SlabAlO-2 SlabAlO_2
# job was stored with the job ID  39
# SlabNiO2-s12 SlabNiO2_s12
# job was stored with the job ID  40
# SlabNiO-2 SlabNiO_2
# job was stored with the job ID  41
# SlabAlO2-s12 SlabAlO2_s12
# job was stored with the job ID  42
# SlabNiO2-s23 SlabNiO2_s23
# job was stored with the job ID  43
# Al2O3-Olayer2 Al2O3_Olayer2
# job was stored with the job ID  44
# SlabAlO2-s18 SlabAlO2_s18
# job was stored with the job ID  45
# SlabAlO2-s5 SlabAlO2_s5
# job was stored with the job ID  46
# SlabNiO2-s06 SlabNiO2_s06
# job was stored with the job ID  47
# Ni-slab-Olayer4 Ni_slab_Olayer4
# job was stored with the job ID  48
# SlabAlO2-s10 SlabAlO2_s10
# job was stored with the job ID  49
# SlabAlO2-s8 SlabAlO2_s8
# job was stored with the job ID  50
# SlabNiO2-s11 SlabNiO2_s11
# job was stored with the job ID  51
# SlabNiO2-2 SlabNiO2_2
# job was stored with the job ID  52
# 2022-09-12 15:08:30,477 - pyiron_log - WARNING - Unable to parse the vasprun.xml file. Will attempt to get data from OUTCAR
# SlabNiO2-s01 SlabNiO2_s01
# job was stored with the job ID  53
# SlabAlO2-s20 SlabAlO2_s20
# job was stored with the job ID  54
# SlabNiO2-s18 SlabNiO2_s18
# job was stored with the job ID  55
# SlabNiO2-s26 SlabNiO2_s26
# job was stored with the job ID  56
# PureAl2O3 PureAl2O3
# job was stored with the job ID  57
# SlabNiO2-s25 SlabNiO2_s25
# job was stored with the job ID  58
# SlabNiO2-s05 SlabNiO2_s05
# job was stored with the job ID  59
# SlabAl SlabAl
# job was stored with the job ID  60
# SlabNiO2-s22 SlabNiO2_s22
# job was stored with the job ID  61
# SlabNiO2-s04 SlabNiO2_s04
# job was stored with the job ID  62
# SlabAlO2-s4 SlabAlO2_s4
# job was stored with the job ID  63
# SlabNiO2-1 SlabNiO2_1
# job was stored with the job ID  64
# 2022-09-12 15:08:36,182 - pyiron_log - WARNING - Unable to parse the vasprun.xml file. Will attempt to get data from OUTCAR
# SlabNiO2-s24 SlabNiO2_s24
# job was stored with the job ID  65
# NiO-1 NiO_1
# job was stored with the job ID  66
# NiAlO-2 NiAlO_2
# job was stored with the job ID  67
# SlabAlO-1 SlabAlO_1
# job was stored with the job ID  68
# SlabNiO2-s07 SlabNiO2_s07
# job was stored with the job ID  69
# NiO-Slab NiO_Slab
# job was stored with the job ID  70
# Ni-slab-Olayer1 Ni_slab_Olayer1
# job was stored with the job ID  71
# NiO-Slab-O NiO_Slab_O
# job was stored with the job ID  72
# SlabAlO2-s2 SlabAlO2_s2
# job was stored with the job ID  73
# AlO-2 AlO_2
# job was stored with the job ID  74
# O4-3 O4_3
# job was stored with the job ID  75
# SlabAlO2-s23 SlabAlO2_s23
# job was stored with the job ID  76
# O2-short O2_short
# job was stored with the job ID  77
# SlabAlO2-s1 SlabAlO2_s1
# job was stored with the job ID  78
# SlabNiO2-s15 SlabNiO2_s15
# job was stored with the job ID  79
# SlabAlO2-s14 SlabAlO2_s14
# job was stored with the job ID  80
# Al2O3-O Al2O3_O
# job was stored with the job ID  81
# AlO-1 AlO_1
# job was stored with the job ID  82
# SlabNi SlabNi
# job was stored with the job ID  83
# PureNiO PureNiO
# job was stored with the job ID  84
# O O
# job was stored with the job ID  85
# SlabAlO2-s13 SlabAlO2_s13
# job was stored with the job ID  86
# NiAlO-1 NiAlO_1
# job was stored with the job ID  87
# SlabAlO2-s11 SlabAlO2_s11
# job was stored with the job ID  88
# SlabAlO2-s21 SlabAlO2_s21
# job was stored with the job ID  89
# SlabNiO2-p1 SlabNiO2_p1
# job was stored with the job ID  90
# SlabAlO2-s3 SlabAlO2_s3
# job was stored with the job ID  91
# PureNiAl PureNiAl
# job was stored with the job ID  92

# %%
pr.job_table()[0:20]
# Out:
#     id    status chemicalformula              job            subjob  \
# 0    1  finished         Al252O2     SlabAlO2_s19     /SlabAlO2_s19
# 1    2  finished         Ni252O2     SlabNiO2_s16     /SlabNiO2_s16
# 2    3  finished           Al256           PureAl           /PureAl
# 3    4  finished       Ni252O128  Ni_slab_Olayer2  /Ni_slab_Olayer2
# 4    5  finished         Ni252O2     SlabNiO2_s27     /SlabNiO2_s27
# 5    6  finished         Ni252O2     SlabNiO2_s08     /SlabNiO2_s08
# 6    7  finished         Ni252O2     SlabNiO2_s17     /SlabNiO2_s17
# 7    8  finished              O4             O4_2             /O4_2
# 8    9  finished       Al108O164         Al2O3_O2         /Al2O3_O2
# 9   10  finished         Al252O2     SlabAlO2_s15     /SlabAlO2_s15
# 10  11  finished         Ni252O2     SlabNiO2_s02     /SlabNiO2_s02
# 11  12  finished         Al252O2     SlabAlO2_s24     /SlabAlO2_s24
# 12  13  finished         Al252O2     SlabAlO2_s17     /SlabAlO2_s17
# 13  14  finished           Ni256           PureNi           /PureNi
# 14  15  finished              O4             O4_1             /O4_1
# 15  16  finished         Al252O2     SlabAlO2_s22     /SlabAlO2_s22
# 16  17  finished       Al108O226    Al2O3_Olayer1    /Al2O3_Olayer1
# 17  18  finished         Ni252O2     SlabNiO2_s21     /SlabNiO2_s21
# 18  19  finished       Ni108O108    NiO_supercell    /NiO_supercell
# 19  20  finished       Ni125O127      NiO_Slab_O2      /NiO_Slab_O2
#
#    projectpath  \
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
#
#                                                                             project  \
# 0   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 1   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 2   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 3   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 4   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 5   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 6   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 7   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 8   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 9   /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 10  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 11  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 12  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 13  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 14  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 15  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 16  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 17  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 18  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
# 19  /store/Terry_project/NiAlO_EDIP_fitting_DFT/notebooks/import_and_change_format/
#
#                     timestart timestop totalcputime          computer  \
# 0  2022-09-12 15:07:48.369806     None         None  pyiron@artemis#1
# 1  2022-09-12 15:07:48.718771     None         None  pyiron@artemis#1
# 2  2022-09-12 15:07:49.125103     None         None  pyiron@artemis#1
# 3  2022-09-12 15:07:49.460131     None         None  pyiron@artemis#1
# 4  2022-09-12 15:07:51.054733     None         None  pyiron@artemis#1
# 5  2022-09-12 15:07:51.460018     None         None  pyiron@artemis#1
# 6  2022-09-12 15:07:51.844127     None         None  pyiron@artemis#1
# 7  2022-09-12 15:07:52.372737     None         None  pyiron@artemis#1
# 8  2022-09-12 15:07:52.639390     None         None  pyiron@artemis#1
# 9  2022-09-12 15:07:54.270093     None         None  pyiron@artemis#1
# 10 2022-09-12 15:07:54.586377     None         None  pyiron@artemis#1
# 11 2022-09-12 15:07:55.104985     None         None  pyiron@artemis#1
# 12 2022-09-12 15:07:55.423024     None         None  pyiron@artemis#1
# 13 2022-09-12 15:07:55.733056     None         None  pyiron@artemis#1
# 14 2022-09-12 15:07:56.097755     None         None  pyiron@artemis#1
# 15 2022-09-12 15:07:56.368914     None         None  pyiron@artemis#1
# 16 2022-09-12 15:07:56.687390     None         None  pyiron@artemis#1
# 17 2022-09-12 15:07:58.441797     None         None  pyiron@artemis#1
# 18 2022-09-12 15:07:58.860297     None         None  pyiron@artemis#1
# 19 2022-09-12 15:07:59.202356     None         None  pyiron@artemis#1
#
#    hamilton hamversion parentid masterid
# 0      Vasp       None     None     None
# 1      Vasp       None     None     None
# 2      Vasp       None     None     None
# 3      Vasp       None     None     None
# 4      Vasp       None     None     None
# 5      Vasp       None     None     None
# 6      Vasp       None     None     None
# 7      Vasp       None     None     None
# 8      Vasp       None     None     None
# 9      Vasp       None     None     None
# 10     Vasp       None     None     None
# 11     Vasp       None     None     None
# 12     Vasp       None     None     None
# 13     Vasp       None     None     None
# 14     Vasp       None     None     None
# 15     Vasp       None     None     None
# 16     Vasp       None     None     None
# 17     Vasp       None     None     None
# 18     Vasp       None     None     None
# 19     Vasp       None     None     None

# %%
jobs = []
for job in pr.iter_jobs():
    jobs.append(job)
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]

# %%
def get_structure_and_write_lammps(job, iteration):
    # if iteration < 0:
    #     iteration = len(job['output/generic/steps']) -1
    job_path = '/store/Terry_project/NiAlO_EDIP_fitting_DFT/DATA/' + job.name.replace('_', '-')
    name_base = job.name + '_iter_' + str(iteration) + '_lmp.data'
    name_no_ox = job.name + '_iter_' + str(iteration) + '_no_ox_lmp.data'
    #structure = job.get_structure(iteration_step=iteration)
    structure = job.get_final_structure()
    ase_obj = structure.to_ase()
    write_lammps_data(job_path + '/' + name_base, ase_obj)
    ase_obj_no_ox = ase_obj.copy()
    del ase_obj_no_ox[[atom.index for atom in ase_obj_no_ox if atom.symbol=='O']]
    write_lammps_data(job_path + '/' + name_no_ox, ase_obj_no_ox)

# %%
a = jobs[0]
a.get_final_structure()
# Out:
# /tmp/ipykernel_33625/3006347858.py:2: DeprecationWarning: pyiron_atomistics.atomistics.job.atomistic.get_final_structure is deprecated: Use get_structure().
#   a.get_final_structure()
# Al: [  2.3620401  -11.45372008  -6.61281006]
# Al: [  2.3620401  -14.31714011 -11.57241005]
# Al: [ 2.3620401  -8.59028991 -1.65319995]
# Al: [  2.3620401  -17.18057011  -6.61281006]
# Al: [  2.3620401  -20.04400011 -11.57241005]
# Al: [  2.3620401  -14.31713994  -1.65319995]
# Al: [ 2.3620401  -5.72686008 -6.61281006]
# Al: [  2.3620401   -8.59029008 -11.57241005]
# Al: [ 2.3620401  -2.86342991 -1.65319995]
# Al: [  4.71078    -14.31714003  -8.26601001]
# Al: [  4.71078    -17.18057002 -13.22561   ]
# Al: [  4.71078    -11.45372008  -3.30640004]
# Al: [  4.71078    -20.04400002  -8.26601001]
# Al: [  4.71078    -22.90743002 -13.22561   ]
# Al: [  4.71078    -17.18056994  -3.30640004]
# Al: [ 16.3418001  -15.74886001 -14.05221005]
# Al: [ 16.3418001  -10.02200001  -4.13299994]
# Al: [ 16.3418001  -12.88543001  -9.09261005]
# Al: [ 16.3418001  -21.47572    -14.05221005]
# Al: [ 16.3418001  -15.74886001  -4.13299994]
# Al: [ 16.3418001  -18.61229001  -9.09261005]
# O: [ 18.0399999  -10.02199993  -7.15999998]
# O: [ 18.0399999  -10.02200336  -6.06299997]
# pbc: [ True  True  True]
# cell:
# Cell([[0.0, -17.18057346, 0.0], [0.0, -8.59028673, -14.87881307], [30.0, 0.0, 0.0]])

# %%
get_structure_and_write_lammps(jobs[0], "last")
# Out:
# /tmp/ipykernel_33625/3854039722.py:8: DeprecationWarning: pyiron_atomistics.atomistics.job.atomistic.get_final_structure is deprecated: Use get_structure().
#   structure = job.get_final_structure()

# %%
for j in jobs:
    print(j.name)
    get_structure_and_write_lammps(j, "last")
# Out:
# /tmp/ipykernel_33625/3854039722.py:8: DeprecationWarning: pyiron_atomistics.atomistics.job.atomistic.get_final_structure is deprecated: Use get_structure().
#   structure = job.get_final_structure()
# SlabAlO2_s19
# SlabNiO2_s16
# PureAl
# Ni_slab_Olayer2
# SlabNiO2_s27
# SlabNiO2_s08
# SlabNiO2_s17
# O4_2
# Al2O3_O2
# SlabAlO2_s15
# SlabNiO2_s02
# SlabAlO2_s24
# SlabAlO2_s17
# PureNi
# O4_1
# SlabAlO2_s22
# Al2O3_Olayer1
# SlabNiO2_s21
# NiO_supercell
# NiO_Slab_O2
# Al_slab_Olayer1
# SlabAlO2_s16
# Al_slab_Olayer4
# NiO_2
# O2
# SlabNiO_1
# Al_slab_Olayer2
# SlabAlO2_s6
# Al2O3_Olayer4
# SlabAlO2_2
# Al2O3_trigonal
# SlabAlO2_s7
# SlabAlO2_s9
# SlabAlO2_1
# SlabNiO2_s28
# SlabNiO2_s03
# SlabNiO2_s13
# SlabNiO2_s14
# SlabAlO_2
# SlabNiO2_s12
# SlabNiO_2
# SlabAlO2_s12
# SlabNiO2_s23
# Al2O3_Olayer2
# SlabAlO2_s18
# SlabAlO2_s5
# SlabNiO2_s06
# Ni_slab_Olayer4
# SlabAlO2_s10
# SlabAlO2_s8
# SlabNiO2_s11
# SlabNiO2_2
# SlabNiO2_s01
# SlabAlO2_s20
# SlabNiO2_s18
# SlabNiO2_s26
# PureAl2O3
# SlabNiO2_s25
# SlabNiO2_s05
# SlabAl
# SlabNiO2_s22
# SlabNiO2_s04
# SlabAlO2_s4
# SlabNiO2_1
# SlabNiO2_s24
# NiO_1
# NiAlO_2
# SlabAlO_1
# SlabNiO2_s07
# NiO_Slab
# Ni_slab_Olayer1
# NiO_Slab_O
# SlabAlO2_s2
# AlO_2
# O4_3
# SlabAlO2_s23
# O2_short
# SlabAlO2_s1
# SlabNiO2_s15
# SlabAlO2_s14
# Al2O3_O
# AlO_1
# SlabNi
# PureNiO
# O
# SlabAlO2_s13
# NiAlO_1
# SlabAlO2_s11
# SlabAlO2_s21
# SlabNiO2_p1
# SlabAlO2_s3
# PureNiAl
